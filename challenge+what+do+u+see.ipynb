# %%
import numpy as np
import pandas as pd
df = pd.read_csv('honeyproduction.csv')
print(df)
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# 5      FL  230000.0           98  22540000.0   4508000.0        0.64
# 6      GA   75000.0           56   4200000.0    307000.0        0.69
# 7      HI    8000.0          118    944000.0     66000.0        0.77
# 8      ID  120000.0           50   6000000.0   2220000.0        0.65
# 9      IL    9000.0           71    639000.0    204000.0        1.19
# 10     IN    9000.0           92    828000.0    489000.0        0.85
# 11     IA   50000.0           78   3900000.0   2301000.0        0.70
# 12     KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['totalprod'], color='blue')
plt.title('total prod')
plt.show()

# %%
df.plot(kind='scatter', x='numcol',y= 'yieldpercol')
df.plot(kind='line')
plt.show()
#line and scatter

# %%
plt.hist(x, normed=True, color='blue', bins=np.arange(-10, 40), alpha=.5) 
plt.hist(y, normed=True, color='red', bins=np.arange(-10, 40), alpha=.5)
plt.title('Normed histograms')
plt.xlabel('Random Values')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-f6fd7a610af6> in <module>()
#       1
# ----> 2 x = np.normal(df.numcol)
#       3 plt.hist (x, bins= 40)
#       4 plt.show()
#
# AttributeError: module 'numpy' has no attribute 'normal'

# %%
df = pd.read_csv('honeyproduction.csv')
x= ('numcol')
df.hist(x)
plt.show()

# %%
df = pd.read_csv('honeyproduction.csv')
x= ('numcol')
df.boxplot(x)
plt.show()
#histogram.

# %%
#boxplot

# %%
#would like to learn how to space the values on the axises.
#Not sure what criteria I was supposed to visualize from the challenge (What should the axis represent?)
#I chose the same variable (numcol) for all.
#I would like to learn how to generate and read the plots more clearly.
